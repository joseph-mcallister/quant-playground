# %%
from __future__ import (absolute_import, division, print_function,
                        unicode_literals)

import datetime  # For datetime objects
import os.path  # To manage paths
import sys  # To find out the script name (in argv[0])

import backtrader as bt
import backtrader.analyzers as btanalyzers
import pandas as pd
import numpy as np
import pickle

# %%
def moving_average(x, w):
        moving_avg = np.convolve(x, np.ones(w), 'valid') / w
        padding = np.full_like(np.empty(w), np.nan)
        return np.insert(moving_avg, 0, padding)

def moving_avg_diff(short, long):
        return (short - long) / long


def get_X_y(df, binary_output=True):
    
    min_period = 30
    
    percent_change = (df["Close"] - df["Close"].shift(1)) / df["Close"].shift(1)
    print(percent_change[:5])

    y = percent_change.copy()
    
    print(len(y))
    
    ## TEMP
    if binary_output == True:
        y = np.zeros(percent_change.shape)
        y[np.where(percent_change > 0)] = 1
    else:
        y = y.to_numpy()
    
    moving_average_1_day = moving_average(df["Close"], 1)
    moving_average_2_day = moving_average(df["Close"], 2)
    moving_average_3_day = moving_average(df["Close"], 3)
    moving_average_4_day = moving_average(df["Close"], 4)
    moving_average_5_day = moving_average(df["Close"], 5)
    moving_average_6_day = moving_average(df["Close"], 6)
    moving_average_7_day = moving_average(df["Close"], 7)
    moving_average_14_day = moving_average(df["Close"], 14)
    moving_average_30_day = moving_average(df["Close"], 30)
    
    mv_1d_2d = moving_avg_diff(moving_average_1_day, moving_average_2_day)
    mv_1d_3d = moving_avg_diff(moving_average_1_day, moving_average_3_day)
    mv_2d_4d = moving_avg_diff(moving_average_1_day, moving_average_3_day)
    mv_3d_7d = moving_avg_diff(moving_average_3_day, moving_average_7_day)
    mv_7d_14d = moving_avg_diff(moving_average_7_day, moving_average_14_day)
    mv_7d_30d = moving_avg_diff(moving_average_7_day, moving_average_30_day)
        
    X = np.stack((mv_1d_2d, mv_1d_3d, mv_3d_7d, mv_7d_14d, mv_7d_30d), axis=1)
    X = X[min_period:len(X)-1]
    y = y[min_period:]
    
    print(len(X), len(y))
    
    return (X, y)

# %%
df = pd.read_csv("../../data/clean/bitcoin_prices.csv")
df = df.iloc[::24, :]

df["Time"] = pd.to_datetime(df['Time'],unit='s')
df.set_index(pd.DatetimeIndex(df['Time']), inplace=True, drop=True)
start_date = datetime.datetime(2015,7,1)
df = df[df["Time"] > start_date]

offset = 30 # TODO: Refactor to output ox get_features
X, y = get_X_y(df)
df = df[offset:]
for i in range(0, len(X[0,:])):
    df["X_" + str(i)] = X[:,i]
df.describe()
print(df.columns)
# Out:
# Time
# 2019-07-01 21:00:00         NaN
# 2019-07-02 21:00:00    0.011890
# 2019-07-03 21:00:00    0.066929
# 2019-07-04 21:00:00    0.014537
# 2019-07-05 21:00:00   -0.041214
# Name: Close, dtype: float64
# 546
# 516 516
# Index(['Unnamed: 0', 'Time', 'Low', 'High', 'Open', 'Close', 'Volume', 'X_0',
#        'X_1', 'X_2', 'X_3', 'X_4'],
#       dtype='object')

# %%
class CommInfoFractional(bt.CommissionInfo):
    def getsize(self, price, cash):
        '''Returns fractional size for cash operation @price'''
        return self.p.leverage * (cash / price)

# %%
# Create a Stratey
class NNStrategy(bt.Strategy):

    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        self.dataclose = self.datas[0].close
        self.X_0 = self.datas[0].X_0
        self.X_1 = self.datas[0].X_1
        self.X_2 = self.datas[0].X_2
        self.X_3 = self.datas[0].X_3
        self.X_4 = self.datas[0].X_4

        # To keep track of pending orders and buy price/commission
        self.order = None
        self.buyprice = None
        self.buycomm = None
        
        filename = "../../models/pickles/neural_net_v2_daily_price"
        self.clf = pickle.load(open(filename, 'rb'))

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:  # Sell
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            if order.status == order.Canceled:
                self.log("Order Cancelled")
            elif order.status == order.Margin:
                self.log("Order Margin")
            else:
                self.log("Order Rejected")
            self.log(order.status)

        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))

    def next(self):
        # Simply log the closing price of the series from the reference
#         self.log('Close, %.2f' % self.dataclose[0])

        # Check if an order is pending ... if yes, we cannot send a 2nd one
        print("Cash available: " + str(self.broker.get_cash()))
        if self.order:
            return
    
        X = [[self.X_0[0], self.X_1[0], self.X_2[0], self.X_3[0], self.X_4[0]]]
        pred = self.clf.predict(X)[0]
#         if not self.position:
        print(pred, "no position", "new buy" if pred == 1 else "sit out")
        if pred == 1:
            self.log('BUY CREATE, %.2f' % self.dataclose[0])

            # Cancel existing orders 
            self.broker.cancel(self.order)

            self.buy(exectype=bt.Order.Market, size=(self.broker.get_cash() * 0.999 / self.data.close[0]))
                
        elif self.position and pred == 0:
            print(pred, "have active position", "sell")
            self.log('SELL CREATE, %.2f' % self.dataclose[0])
            size = self.broker.get_value() / self.dataclose[0]
            self.sell(size=self.position.size)
        else:
            print(pred, "have active position", "hold positition")

class PandasData(bt.feeds.PandasData):
    params = (
        ('X_0', 'X_0'),
        ('X_1', 'X_1'),
        ('X_2', 'X_2'),
        ('X_3', 'X_3'),
        ('X_4', 'X_4'),
    )
    lines = ('X_0','X_1', 'X_2', 'X_3', 'X_4')

if __name__ == '__main__':
    # Create a cerebro entity
    cerebro = bt.Cerebro()

    # Add a strategy
    cerebro.addstrategy(NNStrategy)

    data = PandasData(dataname=df)
    cerebro.adddata(data)

    cerebro.broker.setcash(10000)

    cerebro.addsizer(bt.sizers.FixedSize, stake=1)

    cerebro.broker.addcommissioninfo(CommInfoFractional())

    cerebro.broker.set_coc(True) # cheat_on_close to true (allow buying at same price to avoid order failing with margin)

    
    ## Include commission to see algo's returns with Coinbase Fees
    cerebro.broker.setcommission(commission=0.0003, margin=None) 
    
    cerebro.addanalyzer(btanalyzers.SharpeRatio, _name='mysharpe')
    cerebro.addanalyzer(btanalyzers.AnnualReturn, _name='annualreturn')
    cerebro.addanalyzer(btanalyzers.DrawDown, _name='drawdown')
    cerebro.addanalyzer(btanalyzers.Returns, _name='returns')
    cerebro.addanalyzer(btanalyzers.TradeAnalyzer, _name='tradeanalyzer')

    cerebro.addobserver(bt.observers.DrawDown)

    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    strats = cerebro.run()

    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 10000.00
# Cash available: 10000.0
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 10000.0
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 10000.0
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 10000.0
# 1.0 no position new buy
# 2019-08-03, BUY CREATE, 10847.68
# 2019-08-04, BUY EXECUTED, Price: 10847.68, Cost: 9990.00, Comm 3.00
# Cash available: 7.003
# 0.0 no position sit out
# 0.0 have active position sell
# 2019-08-04, SELL CREATE, 10974.69
# 2019-08-05, SELL EXECUTED, Price: 10974.69, Cost: 9990.00, Comm 3.03
# 2019-08-05, OPERATION PROFIT, GROSS 116.97, NET 110.94
# Cash available: 10110.93876820758
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 10110.93876820758
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 10110.93876820758
# 1.0 no position new buy
# 2019-08-07, BUY CREATE, 11929.13
# 2019-08-08, BUY EXECUTED, Price: 11929.13, Cost: 10100.83, Comm 3.03
# Cash available: 7.080690419376332
# 1.0 no position new buy
# 2019-08-08, BUY CREATE, 11714.90
# 2019-08-09, BUY EXECUTED, Price: 11714.90, Cost: 7.07, Comm 0.00
# Cash available: 0.004958607500689004
# 1.0 no position new buy
# 2019-08-09, BUY CREATE, 11909.89
# 2019-08-10, BUY EXECUTED, Price: 11909.89, Cost: 0.00, Comm 0.00
# Cash available: 3.4725128327323677e-06
# 1.0 no position new buy
# 2019-08-10, BUY CREATE, 11299.80
# 2019-08-11, BUY EXECUTED, Price: 11299.80, Cost: 0.00, Comm 0.00
# Cash available: 2.4318007367624645e-09
# 1.0 no position new buy
# 2019-08-11, BUY CREATE, 11499.85
# 2019-08-12, BUY EXECUTED, Price: 11499.85, Cost: 0.00, Comm 0.00
# Cash available: 1.7029900559547361e-12
# 1.0 no position new buy
# 2019-08-12, BUY CREATE, 11390.01
# 2019-08-13, BUY EXECUTED, Price: 11390.01, Cost: 0.00, Comm 0.00
# Cash available: 1.1926039361851276e-15
# 1.0 no position new buy
# 2019-08-13, BUY CREATE, 10855.01
# 2019-08-14, BUY EXECUTED, Price: 10855.01, Cost: 0.00, Comm 0.00
# Cash available: 8.351805365103455e-19
# 1.0 no position new buy
# 2019-08-14, BUY CREATE, 10186.69
# 2019-08-15, BUY EXECUTED, Price: 10186.69, Cost: 0.00, Comm 0.00
# Cash available: 5.848769297181759e-22
# 1.0 no position new buy
# 2019-08-15, BUY CREATE, 10339.90
# 2019-08-16, BUY EXECUTED, Price: 10339.90, Cost: 0.00, Comm 0.00
# Cash available: 4.0958931388154376e-25
# 1.0 no position new buy
# 2019-08-16, BUY CREATE, 10445.49
# 2019-08-17, BUY EXECUTED, Price: 10445.49, Cost: 0.00, Comm 0.00
# Cash available: 2.8683539651130785e-28
# 1.0 no position new buy
# 2019-08-17, BUY CREATE, 10139.95
# 2019-08-18, BUY EXECUTED, Price: 10139.95, Cost: 0.00, Comm 0.00
# Cash available: 2.00870828176861e-31
# 1.0 no position new buy
# 2019-08-18, BUY CREATE, 10422.14
# 2019-08-19, BUY EXECUTED, Price: 10422.14, Cost: 0.00, Comm 0.00
# Cash available: 1.4066984097226616e-34
# 1.0 no position new buy
# 2019-08-19, BUY CREATE, 10713.03
# 2019-08-20, BUY EXECUTED, Price: 10713.03, Cost: 0.00, Comm 0.00
# Cash available: 9.851108963286876e-38
# 0.0 no position sit out
# 0.0 have active position sell
# 2019-08-20, SELL CREATE, 10790.54
# 2019-08-21, SELL EXECUTED, Price: 10790.54, Cost: 10107.91, Comm 2.74
# 2019-08-21, OPERATION PROFIT, GROSS -964.64, NET -970.42
# Cash available: 9140.519286279183
# 1.0 no position new buy
# 2019-08-21, BUY CREATE, 10039.99
# 2019-08-22, BUY EXECUTED, Price: 10039.99, Cost: 9131.38, Comm 2.74
# Cash available: 6.401105656180633
# 1.0 no position new buy
# 2019-08-22, BUY CREATE, 10142.89
# 2019-08-23, BUY EXECUTED, Price: 10142.89, Cost: 6.39, Comm 0.00
# Cash available: 0.0044826942910236815
# 1.0 no position new buy
# 2019-08-23, BUY CREATE, 10427.03
# 2019-08-24, BUY EXECUTED, Price: 10427.03, Cost: 0.00, Comm 0.00
# Cash available: 3.1392308120042783e-06
# 0.0 no position sit out
# 0.0 have active position sell
# 2019-08-24, SELL CREATE, 10074.88
# 2019-08-25, SELL EXECUTED, Price: 10074.88, Cost: 9137.78, Comm 2.75
# 2019-08-25, OPERATION PROFIT, GROSS 31.69, NET 26.20
# Cash available: 9166.716566046702
# 1.0 no position new buy
# 2019-08-25, BUY CREATE, 9995.01
# 2019-08-26, BUY EXECUTED, Price: 9995.01, Cost: 9157.55, Comm 2.75
# Cash available: 6.419451611203202
# 1.0 no position new buy
# 2019-08-26, BUY CREATE, 10260.67
# 2019-08-27, BUY EXECUTED, Price: 10260.67, Cost: 6.41, Comm 0.00
# Cash available: 0.004495541963325231
# 0.0 no position sit out
# 0.0 have active position sell
# 2019-08-27, SELL CREATE, 10128.00
# 2019-08-28, SELL EXECUTED, Price: 10128.00, Cost: 9163.96, Comm 2.79
# 2019-08-28, OPERATION PROFIT, GROSS 121.76, NET 116.23
# Cash available: 9282.945795990014
# 1.0 no position new buy
# 2019-08-28, BUY CREATE, 9724.63
# 2019-08-29, BUY EXECUTED, Price: 9724.63, Cost: 9273.66, Comm 2.78
# Cash available: 6.500846940932393
# 1.0 no position new buy
# 2019-08-29, BUY CREATE, 9508.74
# 2019-08-30, BUY EXECUTED, Price: 9508.74, Cost: 6.49, Comm 0.00
# Cash available: 0.00455254311273501
# 1.0 no position new buy
# 2019-08-30, BUY CREATE, 9590.54
# 2019-08-31, BUY EXECUTED, Price: 9590.54, Cost: 0.00, Comm 0.00
# Cash available: 3.1881459418483396e-06
# 0.0 no position sit out
# 0.0 have active position sell
# 2019-08-31, SELL CREATE, 9670.00
# 2019-09-01, SELL EXECUTED, Price: 9670.00, Cost: 9280.16, Comm 2.77
# 2019-09-01, OPERATION PROFIT, GROSS -51.99, NET -57.54
# Cash available: 9225.406866697183
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 9225.406866697183
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 9225.406866697183
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 9225.406866697183
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 9225.406866697183
# 1.0 no position new buy
# 2019-09-05, BUY CREATE, 10559.16
# 2019-09-06, BUY EXECUTED, Price: 10559.16, Cost: 9216.18, Comm 2.76
# Cash available: 6.46055242874794
# 1.0 no position new buy
# 2019-09-06, BUY CREATE, 10424.51
# 2019-09-07, BUY EXECUTED, Price: 10424.51, Cost: 6.45, Comm 0.00
# Cash available: 0.0045243248658520105
# 1.0 no position new buy
# 2019-09-07, BUY CREATE, 10528.23
# 2019-09-08, BUY EXECUTED, Price: 10528.23, Cost: 0.00, Comm 0.00
# Cash available: 3.168384703555928e-06
# 0.0 no position sit out
# 0.0 have active position sell
# 2019-09-08, SELL CREATE, 10421.95
# 2019-09-09, SELL EXECUTED, Price: 10421.95, Cost: 9222.64, Comm 2.73
# 2019-09-09, OPERATION PROFIT, GROSS -119.76, NET -125.26
# Cash available: 9100.14878705739
# 1.0 no position new buy
# 2019-09-09, BUY CREATE, 10286.31
# 2019-09-10, BUY EXECUTED, Price: 10286.31, Cost: 9091.05, Comm 2.73
# Cash available: 6.372834195576962
# 1.0 no position new buy
# 2019-09-10, BUY CREATE, 10096.19
# 2019-09-11, BUY EXECUTED, Price: 10096.19, Cost: 6.37, Comm 0.00
# Cash available: 0.004462895787162911
# 1.0 no position new buy
# 2019-09-11, BUY CREATE, 10167.00
# 2019-09-12, BUY EXECUTED, Price: 10167.00, Cost: 0.00, Comm 0.00
# Cash available: 3.1253659197498206e-06
# 1.0 no position new buy
# 2019-09-12, BUY CREATE, 10417.42
# 2019-09-13, BUY EXECUTED, Price: 10417.42, Cost: 0.00, Comm 0.00
# Cash available: 2.188693753600881e-09
# 0.0 no position sit out
# 0.0 have active position sell
# 2019-09-13, SELL CREATE, 10302.97
# 2019-09-14, SELL EXECUTED, Price: 10302.97, Cost: 9097.42, Comm 2.73
# 2019-09-14, OPERATION PROFIT, GROSS 14.85, NET 9.39
# Cash available: 9109.54045072377
# 1.0 no position new buy
# 2019-09-14, BUY CREATE, 10397.71
# 2019-09-15, BUY EXECUTED, Price: 10397.71, Cost: 9100.43, Comm 2.73
# Cash available: 6.379411177641302
# 1.0 no position new buy
# 2019-09-15, BUY CREATE, 10300.13
# 2019-09-16, BUY EXECUTED, Price: 10300.13, Cost: 6.37, Comm 0.00
# Cash available: 0.004467501647702083
# 1.0 no position new buy
# 2019-09-16, BUY CREATE, 10302.47
# 2019-09-17, BUY EXECUTED, Price: 10302.47, Cost: 0.00, Comm 0.00
# Cash available: 3.1285914038855486e-06
# 1.0 no position new buy
# 2019-09-17, BUY CREATE, 10216.01
# 2019-09-18, BUY EXECUTED, Price: 10216.01, Cost: 0.00, Comm 0.00
# Cash available: 2.1909525601412188e-09
# 1.0 no position new buy
# 2019-09-18, BUY CREATE, 10193.26
# 2019-09-19, BUY EXECUTED, Price: 10193.26, Cost: 0.00, Comm 0.00
# Cash available: 1.5343240778669012e-12
# 1.0 no position new buy
# 2019-09-19, BUY CREATE, 10263.00
# 2019-09-20, BUY EXECUTED, Price: 10263.00, Cost: 0.00, Comm 0.00
# Cash available: 1.0744871517301453e-15
# 1.0 no position new buy
# 2019-09-20, BUY CREATE, 10125.54
# 2019-09-21, BUY EXECUTED, Price: 10125.54, Cost: 0.00, Comm 0.00
# Cash available: 7.524633523566292e-19
# 1.0 no position new buy
# 2019-09-21, BUY CREATE, 9981.86
# 2019-09-22, BUY EXECUTED, Price: 9981.86, Cost: 0.00, Comm 0.00
# Cash available: 5.269500856553646e-22
# 1.0 no position new buy
# 2019-09-22, BUY CREATE, 10047.58
# 2019-09-23, BUY EXECUTED, Price: 10047.58, Cost: 0.00, Comm 0.00
# Cash available: 3.690231449844556e-25
# 0.0 no position sit out
# 0.0 have active position sell
# 2019-09-23, SELL CREATE, 9741.47
# 2019-09-24, SELL EXECUTED, Price: 9741.47, Cost: 9106.81, Comm 2.56
# 2019-09-24, OPERATION PROFIT, GROSS -574.71, NET -580.00
# Cash available: 8529.539213024223
# 1.0 no position new buy
# 2019-09-24, BUY CREATE, 8653.10
# 2019-09-25, BUY EXECUTED, Price: 8653.10, Cost: 8521.01, Comm 2.56
# Cash available: 5.973236310881331
# 1.0 no position new buy
# 2019-09-25, BUY CREATE, 8593.70
# 2019-09-26, BUY EXECUTED, Price: 8593.70, Cost: 5.97, Comm 0.00
# Cash available: 0.004183057388509956
# 1.0 no position new buy
# 2019-09-26, BUY CREATE, 8080.00
# 2019-09-27, BUY EXECUTED, Price: 8080.00, Cost: 0.00, Comm 0.00
# Cash available: 2.929395089173794e-06
# 1.0 no position new buy
# 2019-09-27, BUY CREATE, 8234.24
# 2019-09-28, BUY EXECUTED, Price: 8234.24, Cost: 0.00, Comm 0.00
# Cash available: 2.0514553809485648e-09
# 0.0 no position sit out
# 0.0 have active position sell
# 2019-09-28, SELL CREATE, 8139.70
# 2019-09-29, SELL EXECUTED, Price: 8139.70, Cost: 8526.98, Comm 2.41
# 2019-09-29, OPERATION PROFIT, GROSS -505.88, NET -510.84
# Cash available: 8018.696667490677
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 8018.696667490677
# 1.0 no position new buy
# 2019-09-30, BUY CREATE, 8246.94
# 2019-10-01, BUY EXECUTED, Price: 8246.94, Cost: 8010.68, Comm 2.40
# Cash available: 5.615493276244029
# 1.0 no position new buy
# 2019-10-01, BUY CREATE, 8327.19
# 2019-10-02, BUY EXECUTED, Price: 8327.19, Cost: 5.61, Comm 0.00
# Cash available: 0.003932529941354108
# 1.0 no position new buy
# 2019-10-02, BUY CREATE, 8267.99
# 2019-10-03, BUY EXECUTED, Price: 8267.99, Cost: 0.00, Comm 0.00
# Cash available: 2.753950717929888e-06
# 1.0 no position new buy
# 2019-10-03, BUY CREATE, 8180.94
# 2019-10-04, BUY EXECUTED, Price: 8180.94, Cost: 0.00, Comm 0.00
# Cash available: 1.92859168776611e-09
# 1.0 no position new buy
# 2019-10-04, BUY CREATE, 8185.00
# 2019-10-05, BUY EXECUTED, Price: 8185.00, Cost: 0.00, Comm 0.00
# Cash available: 1.3505927589425195e-12
# 1.0 no position new buy
# 2019-10-05, BUY CREATE, 8163.54
# 2019-10-06, BUY EXECUTED, Price: 8163.54, Cost: 0.00, Comm 0.00
# Cash available: 9.458201090873633e-16
# 1.0 no position new buy
# 2019-10-06, BUY CREATE, 7926.98
# 2019-10-07, BUY EXECUTED, Price: 7926.98, Cost: 0.00, Comm 0.00
# Cash available: 6.623578223938605e-19
# 1.0 no position new buy
# 2019-10-07, BUY CREATE, 8209.39
# 2019-10-08, BUY EXECUTED, Price: 8209.39, Cost: 0.00, Comm 0.00
# Cash available: 4.6384918302239915e-22
# 0.0 no position sit out
# 0.0 have active position sell
# 2019-10-08, SELL CREATE, 8164.90
# 2019-10-09, SELL EXECUTED, Price: 8164.90, Cost: 8016.29, Comm 2.38
# 2019-10-09, OPERATION PROFIT, GROSS -79.80, NET -84.58
# Cash available: 7934.111769953018
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 7934.111769953018
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 7934.111769953018
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 7934.111769953018
# 1.0 no position new buy
# 2019-10-12, BUY CREATE, 8340.00
# 2019-10-13, BUY EXECUTED, Price: 8340.00, Cost: 7926.18, Comm 2.38
# Cash available: 5.556258472498314
# 0.0 no position sit out
# 0.0 have active position sell
# 2019-10-13, SELL CREATE, 8251.39
# 2019-10-14, SELL EXECUTED, Price: 8251.39, Cost: 7926.18, Comm 2.35
# 2019-10-14, OPERATION PROFIT, GROSS -84.21, NET -88.94
# Cash available: 7845.168065670948
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 7845.168065670948
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 7845.168065670948
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 7845.168065670948
# 1.0 no position new buy
# 2019-10-17, BUY CREATE, 8068.58
# 2019-10-18, BUY EXECUTED, Price: 8068.58, Cost: 7837.32, Comm 2.35
# Cash available: 5.4939711963892215
# 0.0 no position sit out
# 0.0 have active position sell
# 2019-10-18, SELL CREATE, 7953.22
# 2019-10-19, SELL EXECUTED, Price: 7953.22, Cost: 7837.32, Comm 2.32
# 2019-10-19, OPERATION PROFIT, GROSS -112.05, NET -116.72
# Cash available: 7728.445671461806
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 7728.445671461806
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 7728.445671461806
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 7728.445671461806
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 7728.445671461806
# 1.0 no position new buy
# 2019-10-23, BUY CREATE, 7436.88
# 2019-10-24, BUY EXECUTED, Price: 7436.88, Cost: 7720.72, Comm 2.32
# Cash available: 5.412230503724383
# 1.0 no position new buy
# 2019-10-24, BUY CREATE, 7450.01
# 2019-10-25, BUY EXECUTED, Price: 7450.01, Cost: 5.41, Comm 0.00
# Cash available: 0.0037901850217581046
# 1.0 no position new buy
# 2019-10-25, BUY CREATE, 8604.00
# 2019-10-26, BUY EXECUTED, Price: 8604.00, Cost: 0.00, Comm 0.00
# Cash available: 2.654266570737037e-06
# 0.0 no position sit out
# 0.0 have active position sell
# 2019-10-26, SELL CREATE, 9249.70
# 2019-10-27, SELL EXECUTED, Price: 9249.70, Cost: 7726.13, Comm 2.88
# 2019-10-27, OPERATION PROFIT, GROSS 1883.31, NET 1878.11
# Cash available: 9606.55979926229
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 9606.55979926229
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 9606.55979926229
# 1.0 no position new buy
# 2019-10-29, BUY CREATE, 9428.83
# 2019-10-30, BUY EXECUTED, Price: 9428.83, Cost: 9596.95, Comm 2.88
# Cash available: 6.727473827423051
# 1.0 no position new buy
# 2019-10-30, BUY CREATE, 9154.43
# 2019-10-31, BUY EXECUTED, Price: 9154.43, Cost: 6.72, Comm 0.00
# Cash available: 0.004711249921344536
# 1.0 no position new buy
# 2019-10-31, BUY CREATE, 9140.35
# 2019-11-01, BUY EXECUTED, Price: 9140.35, Cost: 0.00, Comm 0.00
# Cash available: 3.299288319917204e-06
# 1.0 no position new buy
# 2019-11-01, BUY CREATE, 9279.00
# 2019-11-02, BUY EXECUTED, Price: 9279.00, Cost: 0.00, Comm 0.00
# Cash available: 2.310491610437953e-09
# 1.0 no position new buy
# 2019-11-02, BUY CREATE, 9296.52
# 2019-11-03, BUY EXECUTED, Price: 9296.52, Cost: 0.00, Comm 0.00
# Cash available: 1.618037274789759e-12
# 1.0 no position new buy
# 2019-11-03, BUY CREATE, 9155.18
# 2019-11-04, BUY EXECUTED, Price: 9155.18, Cost: 0.00, Comm 0.00
# Cash available: 1.1331115035353136e-15
# 1.0 no position new buy
# 2019-11-04, BUY CREATE, 9442.99
# 2019-11-05, BUY EXECUTED, Price: 9442.99, Cost: 0.00, Comm 0.00
# Cash available: 7.935179859257393e-19
# 1.0 no position new buy
# 2019-11-05, BUY CREATE, 9355.90
# 2019-11-06, BUY EXECUTED, Price: 9355.90, Cost: 0.00, Comm 0.00
# Cash available: 5.55700645543776e-22
# 1.0 no position new buy
# 2019-11-06, BUY CREATE, 9314.84
# 2019-11-07, BUY EXECUTED, Price: 9314.84, Cost: 0.00, Comm 0.00
# Cash available: 3.8915716207427826e-25
# 1.0 no position new buy
# 2019-11-07, BUY CREATE, 9209.72
# 2019-11-08, BUY EXECUTED, Price: 9209.72, Cost: 0.00, Comm 0.00
# Cash available: 2.725267606006298e-28
# 1.0 no position new buy
# 2019-11-08, BUY CREATE, 8865.36
# 2019-11-09, BUY EXECUTED, Price: 8865.36, Cost: 0.00, Comm 0.00
# Cash available: 1.9085049044863902e-31
# 1.0 no position new buy
# 2019-11-09, BUY CREATE, 8799.99
# 2019-11-10, BUY EXECUTED, Price: 8799.99, Cost: 0.00, Comm 0.00
# Cash available: 1.336525984611848e-34
# 1.0 no position new buy
# 2019-11-10, BUY CREATE, 9040.27
# 2019-11-11, BUY EXECUTED, Price: 9040.27, Cost: 0.00, Comm 0.00
# Cash available: 9.359691470237539e-38
# 1.0 no position new buy
# 2019-11-11, BUY CREATE, 8732.13
# 2019-11-12, BUY EXECUTED, Price: 8732.13, Cost: 0.00, Comm 0.00
# Cash available: 6.554591936607138e-41
# 1.0 no position new buy
# 2019-11-12, BUY CREATE, 8762.48
# 2019-11-13, BUY EXECUTED, Price: 8762.48, Cost: 0.00, Comm 0.00
# Cash available: 4.590180733205564e-44
# 1.0 no position new buy
# 2019-11-13, BUY CREATE, 8752.24
# 2019-11-14, BUY EXECUTED, Price: 8752.24, Cost: 0.00, Comm 0.00
# Cash available: 3.214503567463952e-47
# 1.0 no position new buy
# 2019-11-14, BUY CREATE, 8649.34
# 2019-11-15, BUY EXECUTED, Price: 8649.34, Cost: 0.00, Comm 0.00
# Cash available: 2.2511168482950006e-50
# 1.0 no position new buy
# 2019-11-15, BUY CREATE, 8452.77
# 2019-11-16, BUY EXECUTED, Price: 8452.77, Cost: 0.00, Comm 0.00
# Cash available: 1.5764571288610243e-53
# 1.0 no position new buy
# 2019-11-16, BUY CREATE, 8477.53
# 2019-11-17, BUY EXECUTED, Price: 8477.53, Cost: 0.00, Comm 0.00
# Cash available: 1.1039929273414166e-56
# 1.0 no position new buy
# 2019-11-17, BUY CREATE, 8553.32
# 2019-11-18, BUY EXECUTED, Price: 8553.32, Cost: 0.00, Comm 0.00
# Cash available: 7.731262470171498e-60
# 0.0 no position sit out
# 0.0 have active position sell
# 2019-11-18, SELL CREATE, 8216.38
# 2019-11-19, SELL EXECUTED, Price: 8216.38, Cost: 9603.68, Comm 2.51
# 2019-11-19, OPERATION PROFIT, GROSS -1234.76, NET -1240.15
# Cash available: 8366.409962279151
# 1.0 no position new buy
# 2019-11-19, BUY CREATE, 8105.99
# 2019-11-20, BUY EXECUTED, Price: 8105.99, Cost: 8358.04, Comm 2.51
# Cash available: 5.858996896583278
# 1.0 no position new buy
# 2019-11-20, BUY CREATE, 8086.43
# 2019-11-21, BUY EXECUTED, Price: 8086.43, Cost: 5.85, Comm 0.00
# Cash available: 0.004103055526676971
# 0.0 no position sit out
# 0.0 have active position sell
# 2019-11-21, SELL CREATE, 7591.31
# 2019-11-22, SELL EXECUTED, Price: 7591.31, Cost: 8363.90, Comm 2.35
# 2019-11-22, OPERATION PROFIT, GROSS -531.04, NET -535.90
# Cash available: 7830.508723573963
# 1.0 no position new buy
# 2019-11-22, BUY CREATE, 7347.31
# 2019-11-23, BUY EXECUTED, Price: 7347.31, Cost: 7822.68, Comm 2.35
# Cash available: 5.483705259118869
# 1.0 no position new buy
# 2019-11-23, BUY CREATE, 7289.01
# 2019-11-24, BUY EXECUTED, Price: 7289.01, Cost: 5.48, Comm 0.00
# Cash available: 0.00384023879296064
# 0.0 no position sit out
# 0.0 have active position sell
# 2019-11-24, SELL CREATE, 7046.01
# 2019-11-25, SELL EXECUTED, Price: 7046.01, Cost: 7828.16, Comm 2.25
# 2019-11-25, OPERATION PROFIT, GROSS -320.98, NET -325.58
# Cash available: 7504.931492964646
# 1.0 no position new buy
# 2019-11-25, BUY CREATE, 7210.18
# 2019-11-26, BUY EXECUTED, Price: 7210.18, Cost: 7497.43, Comm 2.25
# Cash available: 5.255703524523211
# 0.0 no position sit out
# 0.0 have active position sell
# 2019-11-26, SELL CREATE, 7114.59
# 2019-11-27, SELL EXECUTED, Price: 7114.59, Cost: 7497.43, Comm 2.22
# 2019-11-27, OPERATION PROFIT, GROSS -99.40, NET -103.87
# Cash available: 7401.0646438240465
# 1.0 no position new buy
# 2019-11-27, BUY CREATE, 7551.61
# 2019-11-28, BUY EXECUTED, Price: 7551.61, Cost: 7393.66, Comm 2.22
# Cash available: 5.182965570069635
# 0.0 no position sit out
# 0.0 have active position sell
# 2019-11-28, SELL CREATE, 7562.53
# 2019-11-29, SELL EXECUTED, Price: 7562.53, Cost: 7393.66, Comm 2.22
# 2019-11-29, OPERATION PROFIT, GROSS 10.69, NET 6.25
# Cash available: 7407.316839892177
# 1.0 no position new buy
# 2019-11-29, BUY CREATE, 7703.83
# 2019-11-30, BUY EXECUTED, Price: 7703.83, Cost: 7399.91, Comm 2.22
# Cash available: 5.187343982976106
# 1.0 no position new buy
# 2019-11-30, BUY CREATE, 7547.28
# 2019-12-01, BUY EXECUTED, Price: 7547.28, Cost: 5.18, Comm 0.00
# Cash available: 0.003632696991277773
# 1.0 no position new buy
# 2019-12-01, BUY CREATE, 7380.00
# 2019-12-02, BUY EXECUTED, Price: 7380.00, Cost: 0.00, Comm 0.00
# Cash available: 2.543977702991186e-06
# 1.0 no position new buy
# 2019-12-02, BUY CREATE, 7314.97
# 2019-12-03, BUY EXECUTED, Price: 7314.97, Cost: 0.00, Comm 0.00
# Cash available: 1.7815475854048789e-09
# 0.0 no position sit out
# 0.0 have active position sell
# 2019-12-03, SELL CREATE, 7329.99
# 2019-12-04, SELL EXECUTED, Price: 7329.99, Cost: 7405.10, Comm 2.11
# 2019-12-04, OPERATION PROFIT, GROSS -359.24, NET -363.58
# Cash available: 7043.7405342333495
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 7043.7405342333495
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 7043.7405342333495
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 7043.7405342333495
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 7043.7405342333495
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 7043.7405342333495
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 7043.7405342333495
# 1.0 no position new buy
# 2019-12-10, BUY CREATE, 7220.69
# 2019-12-11, BUY EXECUTED, Price: 7220.69, Cost: 7036.70, Comm 2.11
# Cash available: 4.9327314961238855
# 1.0 no position new buy
# 2019-12-11, BUY CREATE, 7186.87
# 2019-12-12, BUY EXECUTED, Price: 7186.87, Cost: 4.93, Comm 0.00
# Cash available: 0.003454391866735948
# 0.0 no position sit out
# 0.0 have active position sell
# 2019-12-12, SELL CREATE, 7196.42
# 2019-12-13, SELL EXECUTED, Price: 7196.42, Cost: 7041.62, Comm 2.11
# 2019-12-13, OPERATION PROFIT, GROSS -23.65, NET -27.86
# Cash available: 7015.877634398312
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 7015.877634398312
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 7015.877634398312
# 1.0 no position new buy
# 2019-12-15, BUY CREATE, 7117.33
# 2019-12-16, BUY EXECUTED, Price: 7117.33, Cost: 7008.86, Comm 2.10
# /usr/local/lib/python3.9/site-packages/sklearn/base.py:324: UserWarning: Trying to unpickle estimator LabelBinarizer from version 0.24.1 when using version 1.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/base.py:324: UserWarning: Trying to unpickle estimator MLPClassifier from version 0.24.1 when using version 1.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Cash available: 4.913219107369574
# 0.0 no position sit out
# 0.0 have active position sell
# 2019-12-16, SELL CREATE, 6868.85
# 2019-12-17, SELL EXECUTED, Price: 6868.85, Cost: 7008.86, Comm 2.03
# 2019-12-17, OPERATION PROFIT, GROSS -244.69, NET -248.83
# Cash available: 6767.0525651717535
# 1.0 no position new buy
# 2019-12-17, BUY CREATE, 6614.86
# 2019-12-18, BUY EXECUTED, Price: 6614.86, Cost: 6760.29, Comm 2.03
# Cash available: 4.738966911389095
# 1.0 no position new buy
# 2019-12-18, BUY CREATE, 7130.00
# 2019-12-19, BUY EXECUTED, Price: 7130.00, Cost: 4.73, Comm 0.00
# Cash available: 0.0033186985280455527
# 0.0 no position sit out
# 0.0 have active position sell
# 2019-12-19, SELL CREATE, 7154.00
# 2019-12-20, SELL EXECUTED, Price: 7154.00, Cost: 6765.02, Comm 2.19
# 2019-12-20, OPERATION PROFIT, GROSS 551.01, NET 546.78
# Cash available: 7313.837001246635
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 7313.837001246635
# 1.0 no position new buy
# 2019-12-21, BUY CREATE, 7136.12
# 2019-12-22, BUY EXECUTED, Price: 7136.12, Cost: 7306.52, Comm 2.19
# Cash available: 5.121880051972085
# 1.0 no position new buy
# 2019-12-22, BUY CREATE, 7405.19
# 2019-12-23, BUY EXECUTED, Price: 7405.19, Cost: 5.12, Comm 0.00
# Cash available: 0.0035868526003956383
# 0.0 no position sit out
# 0.0 have active position sell
# 2019-12-23, SELL CREATE, 7315.19
# 2019-12-24, SELL EXECUTED, Price: 7315.19, Cost: 7311.64, Comm 2.25
# 2019-12-24, OPERATION PROFIT, GROSS 183.28, NET 178.84
# Cash available: 7492.678851296117
# 1.0 no position new buy
# 2019-12-24, BUY CREATE, 7245.52
# 2019-12-25, BUY EXECUTED, Price: 7245.52, Cost: 7485.19, Comm 2.25
# Cash available: 5.247122999563214
# 1.0 no position new buy
# 2019-12-25, BUY CREATE, 7211.22
# 2019-12-26, BUY EXECUTED, Price: 7211.22, Cost: 5.24, Comm 0.00
# Cash available: 0.0036745602365941083
# 0.0 no position sit out
# 0.0 have active position sell
# 2019-12-26, SELL CREATE, 7189.77
# 2019-12-27, SELL EXECUTED, Price: 7189.77, Cost: 7490.43, Comm 2.23
# 2019-12-27, OPERATION PROFIT, GROSS -57.61, NET -62.09
# Cash available: 7430.592195504652
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 7430.592195504652
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 7430.592195504652
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 7430.592195504652
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 7430.592195504652
# 1.0 no position new buy
# 2019-12-31, BUY CREATE, 7157.95
# 2020-01-01, BUY EXECUTED, Price: 7157.95, Cost: 7423.16, Comm 2.23
# Cash available: 5.2036437145119425
# 1.0 no position new buy
# 2020-01-01, BUY CREATE, 7216.34
# 2020-01-02, BUY EXECUTED, Price: 7216.34, Cost: 5.20, Comm 0.00
# Cash available: 0.0036441116932725342
# 0.0 no position sit out
# 0.0 have active position sell
# 2020-01-02, SELL CREATE, 6957.97
# 2020-01-03, SELL EXECUTED, Price: 6957.97, Cost: 7428.36, Comm 2.17
# 2020-01-03, OPERATION PROFIT, GROSS -207.58, NET -211.97
# Cash available: 7218.62180401731
# 1.0 no position new buy
# 2020-01-03, BUY CREATE, 7269.30
# 2020-01-04, BUY EXECUTED, Price: 7269.30, Cost: 7211.40, Comm 2.16
# Cash available: 5.0552008493529605
# 0.0 no position sit out
# 0.0 have active position sell
# 2020-01-04, SELL CREATE, 7344.84
# 2020-01-05, SELL EXECUTED, Price: 7344.84, Cost: 7211.40, Comm 2.19
# 2020-01-05, OPERATION PROFIT, GROSS 74.94, NET 70.59
# Cash available: 7289.210837304421
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 7289.210837304421
# 1.0 no position new buy
# 2020-01-06, BUY CREATE, 7576.79
# 2020-01-07, BUY EXECUTED, Price: 7576.79, Cost: 7281.92, Comm 2.18
# Cash available: 5.104634349364247
# 0.0 no position sit out
# 0.0 have active position sell
# 2020-01-07, SELL CREATE, 8022.11
# 2020-01-08, SELL EXECUTED, Price: 8022.11, Cost: 7281.92, Comm 2.31
# 2020-01-08, OPERATION PROFIT, GROSS 427.99, NET 423.49
# Cash available: 7712.702625848198
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 7712.702625848198
# 1.0 no position new buy
# 2020-01-09, BUY CREATE, 7785.00
# 2020-01-10, BUY EXECUTED, Price: 7785.00, Cost: 7704.99, Comm 2.31
# Cash available: 5.401205648881874
# 1.0 no position new buy
# 2020-01-10, BUY CREATE, 8046.47
# 2020-01-11, BUY EXECUTED, Price: 8046.47, Cost: 5.40, Comm 0.00
# Cash available: 0.0037824643159120154
# 1.0 no position new buy
# 2020-01-11, BUY CREATE, 8101.99
# 2020-01-12, BUY EXECUTED, Price: 8101.99, Cost: 0.00, Comm 0.00
# Cash available: 2.648859760433194e-06
# 1.0 no position new buy
# 2020-01-12, BUY CREATE, 8103.15
# 2020-01-13, BUY EXECUTED, Price: 8103.15, Cost: 0.00, Comm 0.00
# Cash available: 1.854996490231401e-09
# 1.0 no position new buy
# 2020-01-13, BUY CREATE, 8130.00
# 2020-01-14, BUY EXECUTED, Price: 8130.00, Cost: 0.00, Comm 0.00
# Cash available: 1.2990540421090444e-12
# 1.0 no position new buy
# 2020-01-14, BUY CREATE, 8737.22
# 2020-01-15, BUY EXECUTED, Price: 8737.22, Cost: 0.00, Comm 0.00
# Cash available: 9.097275456889214e-16
# 1.0 no position new buy
# 2020-01-15, BUY CREATE, 8825.78
# 2020-01-16, BUY EXECUTED, Price: 8825.78, Cost: 0.00, Comm 0.00
# Cash available: 6.370822002459791e-19
# 1.0 no position new buy
# 2020-01-16, BUY CREATE, 8677.98
# 2020-01-17, BUY EXECUTED, Price: 8677.98, Cost: 0.00, Comm 0.00
# Cash available: 4.461486648322296e-22
# 1.0 no position new buy
# 2020-01-17, BUY CREATE, 8909.10
# 2020-01-18, BUY EXECUTED, Price: 8909.10, Cost: 0.00, Comm 0.00
# Cash available: 3.1243790998196472e-25
# 1.0 no position new buy
# 2020-01-18, BUY CREATE, 8915.50
# 2020-01-19, BUY EXECUTED, Price: 8915.50, Cost: 0.00, Comm 0.00
# Cash available: 2.1880026836038735e-28
# 1.0 no position new buy
# 2020-01-19, BUY CREATE, 8718.00
# 2020-01-20, BUY EXECUTED, Price: 8718.00, Cost: 0.00, Comm 0.00
# Cash available: 1.5322582793277388e-31
# 1.0 no position new buy
# 2020-01-20, BUY CREATE, 8673.52
# 2020-01-21, BUY EXECUTED, Price: 8673.52, Cost: 0.00, Comm 0.00
# Cash available: 1.0730404730131319e-34
# 1.0 no position new buy
# 2020-01-21, BUY CREATE, 8722.50
# 2020-01-22, BUY EXECUTED, Price: 8722.50, Cost: 0.00, Comm 0.00
# Cash available: 7.514502432510407e-38
# 1.0 no position new buy
# 2020-01-22, BUY CREATE, 8638.98
# 2020-01-23, BUY EXECUTED, Price: 8638.98, Cost: 0.00, Comm 0.00
# Cash available: 5.26240605348699e-41
# 1.0 no position new buy
# 2020-01-23, BUY CREATE, 8380.49
# 2020-01-24, BUY EXECUTED, Price: 8380.49, Cost: 0.00, Comm 0.00
# Cash available: 3.685262959256468e-44
# 1.0 no position new buy
# 2020-01-24, BUY CREATE, 8497.00
# 2020-01-25, BUY EXECUTED, Price: 8497.00, Cost: 0.00, Comm 0.00
# Cash available: 2.580789650367499e-47
# 1.0 no position new buy
# 2020-01-25, BUY CREATE, 8371.00
# 2020-01-26, BUY EXECUTED, Price: 8371.00, Cost: 0.00, Comm 0.00
# Cash available: 1.8073269921524075e-50
# 1.0 no position new buy
# 2020-01-26, BUY CREATE, 8584.60
# 2020-01-27, BUY EXECUTED, Price: 8584.60, Cost: 0.00, Comm 0.00
# Cash available: 1.2656710926042311e-53
# 1.0 no position new buy
# 2020-01-27, BUY CREATE, 8943.54
# 2020-01-28, BUY EXECUTED, Price: 8943.54, Cost: 0.00, Comm 0.00
# Cash available: 8.863494661504426e-57
# 1.0 no position new buy
# 2020-01-28, BUY CREATE, 9040.61
# 2020-01-29, BUY EXECUTED, Price: 9040.61, Cost: 0.00, Comm 0.00
# Cash available: 6.207105311452696e-60
# 1.0 no position new buy
# 2020-01-29, BUY CREATE, 9355.95
# 2020-01-30, BUY EXECUTED, Price: 9355.95, Cost: 0.00, Comm 0.00
# Cash available: 4.346835849610341e-63
# 1.0 no position new buy
# 2020-01-30, BUY CREATE, 9559.48
# 2020-01-31, BUY EXECUTED, Price: 9559.48, Cost: 0.00, Comm 0.00
# Cash available: 3.0440891454822664e-66
# 1.0 no position new buy
# 2020-01-31, BUY CREATE, 9353.75
# 2020-02-01, BUY EXECUTED, Price: 9353.75, Cost: 0.00, Comm 0.00
# Cash available: 2.1317756285813462e-69
# 1.0 no position new buy
# 2020-02-01, BUY CREATE, 9360.88
# 2020-02-02, BUY EXECUTED, Price: 9360.88, Cost: 0.00, Comm 0.00
# Cash available: 1.492882472695295e-72
# 1.0 no position new buy
# 2020-02-02, BUY CREATE, 9440.01
# 2020-02-03, BUY EXECUTED, Price: 9440.01, Cost: 0.00, Comm 0.00
# Cash available: 1.0454655956284769e-75
# 1.0 no position new buy
# 2020-02-03, BUY CREATE, 9275.37
# 2020-02-04, BUY EXECUTED, Price: 9275.37, Cost: 0.00, Comm 0.00
# Cash available: 7.321395566186619e-79
# 1.0 no position new buy
# 2020-02-04, BUY CREATE, 9133.94
# 2020-02-05, BUY EXECUTED, Price: 9133.94, Cost: 0.00, Comm 0.00
# Cash available: 5.1271733150004475e-82
# 1.0 no position new buy
# 2020-02-05, BUY CREATE, 9688.75
# 2020-02-06, BUY EXECUTED, Price: 9688.75, Cost: 0.00, Comm 0.00
# Cash available: 3.590559472494536e-85
# 1.0 no position new buy
# 2020-02-06, BUY CREATE, 9740.24
# 2020-02-07, BUY EXECUTED, Price: 9740.24, Cost: 0.00, Comm 0.00
# Cash available: 2.51446879858784e-88
# 1.0 no position new buy
# 2020-02-07, BUY CREATE, 9743.30
# 2020-02-08, BUY EXECUTED, Price: 9743.30, Cost: 0.00, Comm 0.00
# Cash available: 1.760882499651174e-91
# 1.0 no position new buy
# 2020-02-08, BUY CREATE, 9925.01
# 2020-02-09, BUY EXECUTED, Price: 9925.01, Cost: 0.00, Comm 0.00
# Cash available: 1.233146014506053e-94
# 1.0 no position new buy
# 2020-02-09, BUY CREATE, 10079.00
# 2020-02-10, BUY EXECUTED, Price: 10079.00, Cost: 0.00, Comm 0.00
# Cash available: 8.635721539584593e-98
# 1.0 no position new buy
# 2020-02-10, BUY CREATE, 9866.15
# 2020-02-11, BUY EXECUTED, Price: 9866.15, Cost: 0.00, Comm 0.00
# Cash available: 6.047595794171258e-101
# 1.0 no position new buy
# 2020-02-11, BUY CREATE, 10241.76
# 2020-02-12, BUY EXECUTED, Price: 10241.76, Cost: 0.00, Comm 0.00
# Cash available: 4.235131334658764e-104
# 1.0 no position new buy
# 2020-02-12, BUY CREATE, 10393.43
# 2020-02-13, BUY EXECUTED, Price: 10393.43, Cost: 0.00, Comm 0.00
# Cash available: 2.965862473661595e-107
# 1.0 no position new buy
# 2020-02-13, BUY CREATE, 10180.94
# 2020-02-14, BUY EXECUTED, Price: 10180.94, Cost: 0.00, Comm 0.00
# Cash available: 2.0769934903055042e-110
# 1.0 no position new buy
# 2020-02-14, BUY CREATE, 10347.34
# 2020-02-15, BUY EXECUTED, Price: 10347.34, Cost: 0.00, Comm 0.00
# Cash available: 1.4545185412608507e-113
# 1.0 no position new buy
# 2020-02-15, BUY CREATE, 9924.41
# 2020-02-16, BUY EXECUTED, Price: 9924.41, Cost: 0.00, Comm 0.00
# Cash available: 1.0185993344448379e-116
# 1.0 no position new buy
# 2020-02-16, BUY CREATE, 9768.01
# 2020-02-17, BUY EXECUTED, Price: 9768.01, Cost: 0.00, Comm 0.00
# Cash available: 7.133251139117065e-120
# 1.0 no position new buy
# 2020-02-17, BUY CREATE, 9646.02
# 2020-02-18, BUY EXECUTED, Price: 9646.02, Cost: 0.00, Comm 0.00
# Cash available: 4.995415772723637e-123
# 1.0 no position new buy
# 2020-02-18, BUY CREATE, 10171.40
# 2020-02-19, BUY EXECUTED, Price: 10171.40, Cost: 0.00, Comm 0.00
# Cash available: 3.498289665638573e-126
# 1.0 no position new buy
# 2020-02-19, BUY CREATE, 9625.42
# 2020-02-20, BUY EXECUTED, Price: 9625.42, Cost: 0.00, Comm 0.00
# Cash available: 2.449852252847013e-129
# 1.0 no position new buy
# 2020-02-20, BUY CREATE, 9608.11
# 2020-02-21, BUY EXECUTED, Price: 9608.11, Cost: 0.00, Comm 0.00
# Cash available: 1.715631532668914e-132
# 1.0 no position new buy
# 2020-02-21, BUY CREATE, 9675.20
# 2020-02-22, BUY EXECUTED, Price: 9675.20, Cost: 0.00, Comm 0.00
# Cash available: 1.2014567623279654e-135
# 1.0 no position new buy
# 2020-02-22, BUY CREATE, 9695.84
# 2020-02-23, BUY EXECUTED, Price: 9695.84, Cost: 0.00, Comm 0.00
# Cash available: 8.413801706582226e-139
# 1.0 no position new buy
# 2020-02-23, BUY CREATE, 9885.01
# 2020-02-24, BUY EXECUTED, Price: 9885.01, Cost: 0.00, Comm 0.00
# Cash available: 5.892185335119703e-142
# 1.0 no position new buy
# 2020-02-24, BUY CREATE, 9605.42
# 2020-02-25, BUY EXECUTED, Price: 9605.42, Cost: 0.00, Comm 0.00
# Cash available: 4.126297390184236e-145
# 1.0 no position new buy
# 2020-02-25, BUY CREATE, 9378.02
# 2020-02-26, BUY EXECUTED, Price: 9378.02, Cost: 0.00, Comm 0.00
# Cash available: 2.8896460623461427e-148
# 1.0 no position new buy
# 2020-02-26, BUY CREATE, 8742.41
# 2020-02-27, BUY EXECUTED, Price: 8742.41, Cost: 0.00, Comm 0.00
# Cash available: 2.023619137460881e-151
# 1.0 no position new buy
# 2020-02-27, BUY CREATE, 8755.43
# 2020-02-28, BUY EXECUTED, Price: 8755.43, Cost: 0.00, Comm 0.00
# Cash available: 1.4171404819639127e-154
# 1.0 no position new buy
# 2020-02-28, BUY CREATE, 8667.24
# 2020-02-29, BUY EXECUTED, Price: 8667.24, Cost: 0.00, Comm 0.00
# Cash available: 9.924234795192497e-158
# 0.0 no position sit out
# 0.0 have active position sell
# 2020-02-29, SELL CREATE, 8634.27
# 2020-03-01, SELL EXECUTED, Price: 8634.27, Cost: 7710.39, Comm 2.57
# 2020-03-01, OPERATION PROFIT, GROSS 840.94, NET 836.06
# Cash available: 8548.760182875212
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 8548.760182875212
# 1.0 no position new buy
# 2020-03-02, BUY CREATE, 8944.30
# 2020-03-03, BUY EXECUTED, Price: 8944.30, Cost: 8540.21, Comm 2.56
# Cash available: 5.986696756067712
# 0.0 no position sit out
# 0.0 have active position sell
# 2020-03-03, SELL CREATE, 8736.37
# 2020-03-04, SELL EXECUTED, Price: 8736.37, Cost: 8540.21, Comm 2.50
# 2020-03-04, OPERATION PROFIT, GROSS -198.54, NET -203.60
# Cash available: 8345.15954793577
# 1.0 no position new buy
# 2020-03-04, BUY CREATE, 8733.49
# 2020-03-05, BUY EXECUTED, Price: 8733.49, Cost: 8336.81, Comm 2.50
# Cash available: 5.844115231420069
# 1.0 no position new buy
# 2020-03-05, BUY CREATE, 9118.13
# 2020-03-06, BUY EXECUTED, Price: 9118.13, Cost: 5.84, Comm 0.00
# Cash available: 0.004092633896563105
# 0.0 no position sit out
# 0.0 have active position sell
# 2020-03-06, SELL CREATE, 9137.51
# 2020-03-07, SELL EXECUTED, Price: 9137.51, Cost: 8342.65, Comm 2.62
# 2020-03-07, OPERATION PROFIT, GROSS 385.68, NET 380.56
# Cash available: 8725.720049334524
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 8725.720049334524
# 1.0 no position new buy
# 2020-03-08, BUY CREATE, 8260.00
# 2020-03-09, BUY EXECUTED, Price: 8260.00, Cost: 8716.99, Comm 2.62
# Cash available: 6.11062175054944
# 1.0 no position new buy
# 2020-03-09, BUY CREATE, 7835.24
# 2020-03-10, BUY EXECUTED, Price: 7835.24, Cost: 6.10, Comm 0.00
# Cash available: 0.004279268411909661
# 1.0 no position new buy
# 2020-03-10, BUY CREATE, 7968.31
# 2020-03-11, BUY EXECUTED, Price: 7968.31, Cost: 0.00, Comm 0.00
# Cash available: 2.996771668859955e-06
# 0.0 no position sit out
# 0.0 have active position sell
# 2020-03-11, SELL CREATE, 7806.82
# 2020-03-12, SELL EXECUTED, Price: 7806.82, Cost: 8723.10, Comm 2.47
# 2020-03-12, OPERATION PROFIT, GROSS -478.27, NET -483.37
# Cash available: 8242.354718237317
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 8242.354718237317
# 1.0 no position new buy
# 2020-03-13, BUY CREATE, 5567.21
# 2020-03-14, BUY EXECUTED, Price: 5567.21, Cost: 8234.11, Comm 2.47
# Cash available: 5.772121009181315
# 1.0 no position new buy
# 2020-03-14, BUY CREATE, 5295.51
# 2020-03-15, BUY EXECUTED, Price: 5295.51, Cost: 5.77, Comm 0.00
# Cash available: 0.004042216342730923
# 0.0 no position sit out
# 0.0 have active position sell
# 2020-03-15, SELL CREATE, 5933.68
# 2020-03-16, SELL EXECUTED, Price: 5933.68, Cost: 8239.88, Comm 2.63
# 2020-03-16, OPERATION PROFIT, GROSS 542.72, NET 537.61
# Cash available: 8779.96576002024
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 8779.96576002024
# 1.0 no position new buy
# 2020-03-17, BUY CREATE, 5455.00
# 2020-03-18, BUY EXECUTED, Price: 5455.00, Cost: 8771.19, Comm 2.63
# Cash available: 6.148610021742721
# 1.0 no position new buy
# 2020-03-18, BUY CREATE, 5376.58
# 2020-03-19, BUY EXECUTED, Price: 5376.58, Cost: 6.14, Comm 0.00
# Cash available: 0.004305871598226646
# 1.0 no position new buy
# 2020-03-19, BUY CREATE, 6262.37
# 2020-03-20, BUY EXECUTED, Price: 6262.37, Cost: 0.00, Comm 0.00
# Cash available: 3.0154018802378134e-06
# 0.0 no position sit out
# 0.0 have active position sell
# 2020-03-20, SELL CREATE, 6237.26
# 2020-03-21, SELL EXECUTED, Price: 6237.26, Cost: 8777.33, Comm 3.01
# 2020-03-21, OPERATION PROFIT, GROSS 1258.79, NET 1253.15
# Cash available: 10033.113933268944
# 1.0 no position new buy
# 2020-03-21, BUY CREATE, 6181.79
# 2020-03-22, BUY EXECUTED, Price: 6181.79, Cost: 10023.08, Comm 3.01
# Cash available: 7.026189687467694
# 1.0 no position new buy
# 2020-03-22, BUY CREATE, 6063.85
# 2020-03-23, BUY EXECUTED, Price: 6063.85, Cost: 7.02, Comm 0.00
# Cash available: 0.004920440638133198
# 1.0 no position new buy
# 2020-03-23, BUY CREATE, 6468.89
# 2020-03-24, BUY EXECUTED, Price: 6468.89, Cost: 0.00, Comm 0.00
# Cash available: 3.4457845788845043e-06
# 0.0 no position sit out
# 0.0 have active position sell
# 2020-03-24, SELL CREATE, 6715.34
# 2020-03-25, SELL EXECUTED, Price: 6715.34, Cost: 10030.10, Comm 3.27
# 2020-03-25, OPERATION PROFIT, GROSS 865.85, NET 859.57
# Cash available: 10892.682058486846
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 10892.682058486846
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 10892.682058486846
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 10892.682058486846
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 10892.682058486846
# 1.0 no position new buy
# 2020-03-29, BUY CREATE, 5895.61
# 2020-03-30, BUY EXECUTED, Price: 5895.61, Cost: 10881.79, Comm 3.26
# Cash available: 7.628145245558973
# 1.0 no position new buy
# 2020-03-30, BUY CREATE, 6549.66
# 2020-03-31, BUY EXECUTED, Price: 6549.66, Cost: 7.62, Comm 0.00
# Cash available: 0.00534199011546508
# 0.0 no position sit out
# 0.0 have active position sell
# 2020-03-31, SELL CREATE, 6460.14
# 2020-04-01, SELL EXECUTED, Price: 6460.14, Cost: 10889.41, Comm 3.58
# 2020-04-01, OPERATION PROFIT, GROSS 1041.87, NET 1035.03
# Cash available: 11927.709802584792
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 11927.709802584792
# 1.0 no position new buy
# 2020-04-02, BUY CREATE, 6841.87
# 2020-04-03, BUY EXECUTED, Price: 6841.87, Cost: 11915.78, Comm 3.57
# Cash available: 8.352975174750352
# 0.0 no position sit out
# 0.0 have active position sell
# 2020-04-03, SELL CREATE, 6736.41
# 2020-04-04, SELL EXECUTED, Price: 6736.41, Cost: 11915.78, Comm 3.52
# 2020-04-04, OPERATION PROFIT, GROSS -183.67, NET -190.76
# Cash available: 11736.9465862116
# 1.0 no position new buy
# 2020-04-04, BUY CREATE, 6880.80
# 2020-04-05, BUY EXECUTED, Price: 6880.80, Cost: 11725.21, Comm 3.52
# Cash available: 8.219383694324454
# 1.0 no position new buy
# 2020-04-05, BUY CREATE, 6766.99
# 2020-04-06, BUY EXECUTED, Price: 6766.99, Cost: 8.21, Comm 0.00
# Cash available: 0.005756034401135694
# 1.0 no position new buy
# 2020-04-06, BUY CREATE, 7300.00
# 2020-04-07, BUY EXECUTED, Price: 7300.00, Cost: 0.01, Comm 0.00
# Cash available: 4.030950891115209e-06
# 1.0 no position new buy
# 2020-04-07, BUY CREATE, 7176.95
# 2020-04-08, BUY EXECUTED, Price: 7176.95, Cost: 0.00, Comm 0.00
# Cash available: 2.8228749090479825e-09
# 1.0 no position new buy
# 2020-04-08, BUY CREATE, 7335.20
# 2020-04-09, BUY EXECUTED, Price: 7335.20, Cost: 0.00, Comm 0.00
# Cash available: 1.9768592988063817e-12
# 1.0 no position new buy
# 2020-04-09, BUY CREATE, 7320.99
# 2020-04-10, BUY EXECUTED, Price: 7320.99, Cost: 0.00, Comm 0.00
# Cash available: 1.3843945669540755e-15
# 1.0 no position new buy
# 2020-04-10, BUY CREATE, 6908.43
# 2020-04-11, BUY EXECUTED, Price: 6908.43, Cost: 0.00, Comm 0.00
# Cash available: 9.694915152379127e-19
# 1.0 no position new buy
# 2020-04-11, BUY CREATE, 6873.00
# 2020-04-12, BUY EXECUTED, Price: 6873.00, Cost: 0.00, Comm 0.00
# Cash available: 6.7893490812111335e-22
# 1.0 no position new buy
# 2020-04-12, BUY CREATE, 7130.57
# 2020-04-13, BUY EXECUTED, Price: 7130.57, Cost: 0.00, Comm 0.00
# Cash available: 4.754581161572206e-25
# 1.0 no position new buy
# 2020-04-13, BUY CREATE, 6846.06
# 2020-04-14, BUY EXECUTED, Price: 6846.06, Cost: 0.00, Comm 0.00
# Cash available: 3.32963318744903e-28
# 1.0 no position new buy
# 2020-04-14, BUY CREATE, 6860.62
# 2020-04-15, BUY EXECUTED, Price: 6860.62, Cost: 0.00, Comm 0.00
# Cash available: 2.3317421211704584e-31
# 1.0 no position new buy
# 2020-04-15, BUY CREATE, 6735.67
# 2020-04-16, BUY EXECUTED, Price: 6735.67, Cost: 0.00, Comm 0.00
# Cash available: 1.6329190074555232e-34
# 1.0 no position new buy
# 2020-04-16, BUY CREATE, 7078.99
# 2020-04-17, BUY EXECUTED, Price: 7078.99, Cost: 0.00, Comm 0.00
# Cash available: 1.143533180921103e-37
# 1.0 no position new buy
# 2020-04-17, BUY CREATE, 7050.70
# 2020-04-18, BUY EXECUTED, Price: 7050.70, Cost: 0.00, Comm 0.00
# Cash available: 8.008162865991424e-41
# 1.0 no position new buy
# 2020-04-18, BUY CREATE, 7229.51
# 2020-04-19, BUY EXECUTED, Price: 7229.51, Cost: 0.00, Comm 0.00
# Cash available: 5.608116455053611e-44
# 1.0 no position new buy
# 2020-04-19, BUY CREATE, 7197.86
# 2020-04-20, BUY EXECUTED, Price: 7197.86, Cost: 0.00, Comm 0.00
# Cash available: 3.9273639534742236e-47
# 1.0 no position new buy
# 2020-04-20, BUY CREATE, 6858.22
# 2020-04-21, BUY EXECUTED, Price: 6858.22, Cost: 0.00, Comm 0.00
# Cash available: 2.75033297661796e-50
# 1.0 no position new buy
# 2020-04-21, BUY CREATE, 6902.81
# 2020-04-22, BUY EXECUTED, Price: 6902.81, Cost: 0.00, Comm 0.00
# Cash available: 1.9260581835256365e-53
# 1.0 no position new buy
# 2020-04-22, BUY CREATE, 7102.69
# 2020-04-23, BUY EXECUTED, Price: 7102.69, Cost: 0.00, Comm 0.00
# Cash available: 1.3488185459228104e-56
# 1.0 no position new buy
# 2020-04-23, BUY CREATE, 7606.54
# 2020-04-24, BUY EXECUTED, Price: 7606.54, Cost: 0.00, Comm 0.00
# Cash available: 9.445776277097634e-60
# 0.0 no position sit out
# 0.0 have active position sell
# 2020-04-24, SELL CREATE, 7503.76
# 2020-04-25, SELL EXECUTED, Price: 7503.76, Cost: 11733.43, Comm 3.84
# 2020-04-25, OPERATION PROFIT, GROSS 1062.45, NET 1055.09
# Cash available: 12792.035358685845
# 1.0 no position new buy
# 2020-04-25, BUY CREATE, 7532.21
# 2020-04-26, BUY EXECUTED, Price: 7532.21, Cost: 12779.24, Comm 3.83
# Cash available: 8.95826236168695
# 1.0 no position new buy
# 2020-04-26, BUY CREATE, 7640.42
# 2020-04-27, BUY EXECUTED, Price: 7640.42, Cost: 8.95, Comm 0.00
# Cash available: 0.006273471131890152
# 1.0 no position new buy
# 2020-04-27, BUY CREATE, 7737.73
# 2020-04-28, BUY EXECUTED, Price: 7737.73, Cost: 0.01, Comm 0.00
# Cash available: 4.393311833662315e-06
# 1.0 no position new buy
# 2020-04-28, BUY CREATE, 7744.67
# 2020-04-29, BUY EXECUTED, Price: 7744.67, Cost: 0.00, Comm 0.00
# Cash available: 3.076636277113402e-09
# 1.0 no position new buy
# 2020-04-29, BUY CREATE, 8870.01
# 2020-04-30, BUY EXECUTED, Price: 8870.01, Cost: 0.00, Comm 0.00
# Cash available: 2.1545683848621675e-12
# 0.0 no position sit out
# 0.0 have active position sell
# 2020-04-30, SELL CREATE, 8764.13
# 2020-05-01, SELL EXECUTED, Price: 8764.13, Cost: 12788.20, Comm 4.46
# 2020-05-01, OPERATION PROFIT, GROSS 2091.41, NET 2083.11
# Cash available: 14875.143208652951
# 1.0 no position new buy
# 2020-05-01, BUY CREATE, 8853.58
# 2020-05-02, BUY EXECUTED, Price: 8853.58, Cost: 14860.27, Comm 4.46
# Cash available: 10.417062789020465
# 1.0 no position new buy
# 2020-05-02, BUY CREATE, 8939.45
# 2020-05-03, BUY EXECUTED, Price: 8939.45, Cost: 10.41, Comm 0.00
# Cash available: 0.007295069071151116
# 1.0 no position new buy
# 2020-05-03, BUY CREATE, 8859.82
# 2020-05-04, BUY EXECUTED, Price: 8859.82, Cost: 0.01, Comm 0.00
# Cash available: 5.108736870526764e-06
# 1.0 no position new buy
# 2020-05-04, BUY CREATE, 8958.20
# 2020-05-05, BUY EXECUTED, Price: 8958.20, Cost: 0.00, Comm 0.00
# Cash available: 3.577648430429903e-09
# 1.0 no position new buy
# 2020-05-05, BUY CREATE, 8977.44
# 2020-05-06, BUY EXECUTED, Price: 8977.44, Cost: 0.00, Comm 0.00
# Cash available: 2.5054271958300926e-12
# 1.0 no position new buy
# 2020-05-06, BUY CREATE, 9296.50
# 2020-05-07, BUY EXECUTED, Price: 9296.50, Cost: 0.00, Comm 0.00
# Cash available: 1.7545506652397612e-15
# 1.0 no position new buy
# 2020-05-07, BUY CREATE, 9887.81
# 2020-05-08, BUY EXECUTED, Price: 9887.81, Cost: 0.00, Comm 0.00
# Cash available: 1.228711830867387e-18
# 1.0 no position new buy
# 2020-05-08, BUY CREATE, 10018.01
# 2020-05-09, BUY EXECUTED, Price: 10018.01, Cost: 0.00, Comm 0.00
# Cash available: 8.604668951563715e-22
# 1.0 no position new buy
# 2020-05-09, BUY CREATE, 9613.90
# 2020-05-10, BUY EXECUTED, Price: 9613.90, Cost: 0.00, Comm 0.00
# Cash available: 6.025849666780272e-25
# 1.0 no position new buy
# 2020-05-10, BUY CREATE, 8726.08
# 2020-05-11, BUY EXECUTED, Price: 8726.08, Cost: 0.00, Comm 0.00
# Cash available: 4.219902521646623e-28
# 1.0 no position new buy
# 2020-05-11, BUY CREATE, 8595.53
# 2020-05-12, BUY EXECUTED, Price: 8595.53, Cost: 0.00, Comm 0.00
# Cash available: 2.955197735909211e-31
# 1.0 no position new buy
# 2020-05-12, BUY CREATE, 8784.39
# 2020-05-13, BUY EXECUTED, Price: 8784.39, Cost: 0.00, Comm 0.00
# Cash available: 2.069524974457187e-34
# 1.0 no position new buy
# 2020-05-13, BUY CREATE, 9363.35
# 2020-05-14, BUY EXECUTED, Price: 9363.35, Cost: 0.00, Comm 0.00
# Cash available: 1.4492883396122834e-37
# 1.0 no position new buy
# 2020-05-14, BUY CREATE, 9782.15
# 2020-05-15, BUY EXECUTED, Price: 9782.15, Cost: 0.00, Comm 0.00
# Cash available: 1.0149366242305134e-40
# 1.0 no position new buy
# 2020-05-15, BUY CREATE, 9414.97
# 2020-05-16, BUY EXECUTED, Price: 9414.97, Cost: 0.00, Comm 0.00
# Cash available: 7.107601179485942e-44
# 1.0 no position new buy
# 2020-05-16, BUY CREATE, 9383.53
# 2020-05-17, BUY EXECUTED, Price: 9383.53, Cost: 0.00, Comm 0.00
# Cash available: 4.977453105993985e-47
# 1.0 no position new buy
# 2020-05-17, BUY CREATE, 9765.77
# 2020-05-18, BUY EXECUTED, Price: 9765.77, Cost: 0.00, Comm 0.00
# Cash available: 3.485710410128017e-50
# 1.0 no position new buy
# 2020-05-18, BUY CREATE, 9685.01
# 2020-05-19, BUY EXECUTED, Price: 9685.01, Cost: 0.00, Comm 0.00
# Cash available: 2.4410430002123864e-53
# 1.0 no position new buy
# 2020-05-19, BUY CREATE, 9688.58
# 2020-05-20, BUY EXECUTED, Price: 9688.58, Cost: 0.00, Comm 0.00
# Cash available: 1.7094624130488335e-56
# 1.0 no position new buy
# ...
# Cash available: 16995.3258383532
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 16995.3258383532
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 16995.3258383532
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 16995.3258383532
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 16995.3258383532
# 1.0 no position new buy
# 2020-09-22, BUY CREATE, 10552.34
# 2020-09-23, BUY EXECUTED, Price: 10552.34, Cost: 16978.33, Comm 5.09
# Cash available: 11.901826684599438
# 0.0 no position sit out
# 0.0 have active position sell
# 2020-09-23, SELL CREATE, 10253.01
# 2020-09-24, SELL EXECUTED, Price: 10253.01, Cost: 16978.33, Comm 4.95
# 2020-09-24, OPERATION PROFIT, GROSS -481.61, NET -491.65
# Cash available: 16503.672261522883
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 16503.672261522883
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 16503.672261522883
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 16503.672261522883
# 1.0 no position new buy
# 2020-09-27, BUY CREATE, 10722.67
# 2020-09-28, BUY EXECUTED, Price: 10722.67, Cost: 16487.17, Comm 4.95
# Cash available: 11.55752168474389
# 1.0 no position new buy
# 2020-09-28, BUY CREATE, 10888.28
# 2020-09-29, BUY EXECUTED, Price: 10888.28, Cost: 11.55, Comm 0.00
# Cash available: 0.008093732435825477
# 0.0 no position sit out
# 0.0 have active position sell
# 2020-09-29, SELL CREATE, 10770.45
# 2020-09-30, SELL EXECUTED, Price: 10770.45, Cost: 16498.71, Comm 4.97
# 2020-09-30, OPERATION PROFIT, GROSS 73.34, NET 63.42
# Cash available: 16567.09257182471
# 1.0 no position new buy
# 2020-09-30, BUY CREATE, 10707.38
# 2020-10-01, BUY EXECUTED, Price: 10707.38, Cost: 16550.53, Comm 4.97
# Cash available: 11.60193492805006
# 1.0 no position new buy
# 2020-10-01, BUY CREATE, 10581.90
# 2020-10-02, BUY EXECUTED, Price: 10581.90, Cost: 11.59, Comm 0.00
# Cash available: 0.008124835030113681
# 1.0 no position new buy
# 2020-10-02, BUY CREATE, 10472.06
# 2020-10-03, BUY EXECUTED, Price: 10472.06, Cost: 0.01, Comm 0.00
# Cash available: 5.689821971589407e-06
# 1.0 no position new buy
# 2020-10-03, BUY CREATE, 10578.61
# 2020-10-04, BUY EXECUTED, Price: 10578.61, Cost: 0.00, Comm 0.00
# Cash available: 3.984582326703829e-09
# 1.0 no position new buy
# 2020-10-04, BUY CREATE, 10647.10
# 2020-10-05, BUY EXECUTED, Price: 10647.10, Cost: 0.00, Comm 0.00
# Cash available: 2.7904030033903666e-12
# 0.0 no position sit out
# 0.0 have active position sell
# 2020-10-05, SELL CREATE, 10742.05
# 2020-10-06, SELL EXECUTED, Price: 10742.05, Cost: 16562.12, Comm 4.98
# 2020-10-06, OPERATION PROFIT, GROSS 53.77, NET 43.81
# Cash available: 16610.904623289105
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 16610.904623289105
# 1.0 no position new buy
# 2020-10-07, BUY CREATE, 10662.10
# 2020-10-08, BUY EXECUTED, Price: 10662.10, Cost: 16594.29, Comm 4.98
# Cash available: 11.632616507688915
# 1.0 no position new buy
# 2020-10-08, BUY CREATE, 10881.75
# 2020-10-09, BUY EXECUTED, Price: 10881.75, Cost: 11.62, Comm 0.00
# Cash available: 0.008146321340333731
# 0.0 no position sit out
# 0.0 have active position sell
# 2020-10-09, SELL CREATE, 11058.32
# 2020-10-10, SELL EXECUTED, Price: 11058.32, Cost: 16605.91, Comm 5.17
# 2020-10-10, OPERATION PROFIT, GROSS 616.86, NET 606.71
# Cash available: 17217.614005275536
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 17217.614005275536
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 17217.614005275536
# 1.0 no position new buy
# 2020-10-12, BUY CREATE, 11690.00
# 2020-10-13, BUY EXECUTED, Price: 11690.00, Cost: 17200.40, Comm 5.16
# Cash available: 12.057495087895042
# 1.0 no position new buy
# 2020-10-13, BUY CREATE, 11456.42
# 2020-10-14, BUY EXECUTED, Price: 11456.42, Cost: 12.05, Comm 0.00
# Cash available: 0.008443863810050745
# 1.0 no position new buy
# 2020-10-14, BUY CREATE, 11380.05
# 2020-10-15, BUY EXECUTED, Price: 11380.05, Cost: 0.01, Comm 0.00
# Cash available: 5.9132378261793975e-06
# 1.0 no position new buy
# 2020-10-15, BUY CREATE, 11503.13
# 2020-10-16, BUY EXECUTED, Price: 11503.13, Cost: 0.00, Comm 0.00
# Cash available: 4.1410404496737394e-09
# 1.0 no position new buy
# 2020-10-16, BUY CREATE, 11346.75
# 2020-10-17, BUY EXECUTED, Price: 11346.75, Cost: 0.00, Comm 0.00
# Cash available: 2.899970626906389e-12
# 1.0 no position new buy
# 2020-10-17, BUY CREATE, 11347.77
# 2020-10-18, BUY EXECUTED, Price: 11347.77, Cost: 0.00, Comm 0.00
# Cash available: 2.0308494300225894e-15
# 1.0 no position new buy
# 2020-10-18, BUY CREATE, 11463.30
# 2020-10-19, BUY EXECUTED, Price: 11463.30, Cost: 0.00, Comm 0.00
# Cash available: 1.4222038558449826e-18
# 1.0 no position new buy
# 2020-10-19, BUY CREATE, 11756.34
# 2020-10-20, BUY EXECUTED, Price: 11756.34, Cost: 0.00, Comm 0.00
# Cash available: 9.95969360248237e-22
# 1.0 no position new buy
# 2020-10-20, BUY CREATE, 11931.73
# 2020-10-21, BUY EXECUTED, Price: 11931.73, Cost: 0.00, Comm 0.00
# Cash available: 6.974773429818788e-25
# 1.0 no position new buy
# 2020-10-21, BUY CREATE, 12939.24
# 2020-10-22, BUY EXECUTED, Price: 12939.24, Cost: 0.00, Comm 0.00
# Cash available: 4.884433832901887e-28
# 1.0 no position new buy
# 2020-10-22, BUY CREATE, 13155.00
# 2020-10-23, BUY EXECUTED, Price: 13155.00, Cost: 0.00, Comm 0.00
# Cash available: 3.4205690131808647e-31
# 1.0 no position new buy
# 2020-10-23, BUY CREATE, 12919.63
# 2020-10-24, BUY EXECUTED, Price: 12919.63, Cost: 0.00, Comm 0.00
# Cash available: 2.3954244799304608e-34
# 1.0 no position new buy
# 2020-10-24, BUY CREATE, 13083.50
# 2020-10-25, BUY EXECUTED, Price: 13083.50, Cost: 0.00, Comm 0.00
# Cash available: 1.6775157632951168e-37
# 1.0 no position new buy
# 2020-10-25, BUY CREATE, 13044.49
# 2020-10-26, BUY EXECUTED, Price: 13044.49, Cost: 0.00, Comm 0.00
# Cash available: 1.1747642890354107e-40
# 1.0 no position new buy
# 2020-10-26, BUY CREATE, 13034.03
# 2020-10-27, BUY EXECUTED, Price: 13034.03, Cost: 0.00, Comm 0.00
# Cash available: 8.226874316115369e-44
# 1.0 no position new buy
# 2020-10-27, BUY CREATE, 13712.93
# 2020-10-28, BUY EXECUTED, Price: 13712.93, Cost: 0.00, Comm 0.00
# Cash available: 5.761280083575251e-47
# 1.0 no position new buy
# 2020-10-28, BUY CREATE, 13207.18
# 2020-10-29, BUY EXECUTED, Price: 13207.18, Cost: 0.00, Comm 0.00
# Cash available: 4.034624442527399e-50
# 1.0 no position new buy
# 2020-10-29, BUY CREATE, 13526.66
# 2020-10-30, BUY EXECUTED, Price: 13526.66, Cost: 0.00, Comm 0.00
# Cash available: 2.8254474971020762e-53
# 1.0 no position new buy
# 2020-10-30, BUY CREATE, 13566.16
# 2020-10-31, BUY EXECUTED, Price: 13566.16, Cost: 0.00, Comm 0.00
# Cash available: 1.9786608822208167e-56
# 1.0 no position new buy
# 2020-10-31, BUY CREATE, 13855.65
# 2020-11-01, BUY EXECUTED, Price: 13855.65, Cost: 0.00, Comm 0.00
# Cash available: 1.3856562158189785e-59
# 1.0 no position new buy
# 2020-11-01, BUY CREATE, 13824.10
# 2020-11-02, BUY EXECUTED, Price: 13824.10, Cost: 0.00, Comm 0.00
# Cash available: 9.703750479380494e-63
# 1.0 no position new buy
# 2020-11-02, BUY CREATE, 13621.36
# 2020-11-03, BUY EXECUTED, Price: 13621.36, Cost: 0.00, Comm 0.00
# Cash available: 6.795536460711663e-66
# 1.0 no position new buy
# 2020-11-03, BUY CREATE, 13740.03
# 2020-11-04, BUY EXECUTED, Price: 13740.03, Cost: 0.00, Comm 0.00
# Cash available: 4.758914183436457e-69
# 1.0 no position new buy
# 2020-11-04, BUY CREATE, 14011.25
# 2020-11-05, BUY EXECUTED, Price: 14011.25, Cost: 0.00, Comm 0.00
# Cash available: 3.3326676026606473e-72
# 1.0 no position new buy
# 2020-11-05, BUY CREATE, 15243.65
# 2020-11-06, BUY EXECUTED, Price: 15243.65, Cost: 0.00, Comm 0.00
# Cash available: 2.3338671221432757e-75
# 1.0 no position new buy
# 2020-11-06, BUY CREATE, 15553.39
# 2020-11-07, BUY EXECUTED, Price: 15553.39, Cost: 0.00, Comm 0.00
# Cash available: 1.6344071456368944e-78
# 1.0 no position new buy
# 2020-11-07, BUY CREATE, 14835.73
# 2020-11-08, BUY EXECUTED, Price: 14835.73, Cost: 0.00, Comm 0.00
# Cash available: 1.1445753240895727e-81
# 1.0 no position new buy
# 2020-11-08, BUY CREATE, 15343.08
# 2020-11-09, BUY EXECUTED, Price: 15343.08, Cost: 0.00, Comm 0.00
# Cash available: 8.015460994600207e-85
# 1.0 no position new buy
# 2020-11-09, BUY CREATE, 15391.11
# 2020-11-10, BUY EXECUTED, Price: 15391.11, Cost: 0.00, Comm 0.00
# Cash available: 5.613227334518861e-88
# 1.0 no position new buy
# 2020-11-10, BUY CREATE, 15387.99
# 2020-11-11, BUY EXECUTED, Price: 15387.99, Cost: 0.00, Comm 0.00
# Cash available: 3.930943102363626e-91
# 1.0 no position new buy
# 2020-11-11, BUY CREATE, 15837.95
# 2020-11-12, BUY EXECUTED, Price: 15837.95, Cost: 0.00, Comm 0.00
# Cash available: 2.752839454585054e-94
# 1.0 no position new buy
# 2020-11-12, BUY CREATE, 16166.99
# 2020-11-13, BUY EXECUTED, Price: 16166.99, Cost: 0.00, Comm 0.00
# Cash available: 1.9278134700457462e-97
# 1.0 no position new buy
# 2020-11-13, BUY CREATE, 16293.58
# 2020-11-14, BUY EXECUTED, Price: 16293.58, Cost: 0.00, Comm 0.00
# Cash available: 1.3500477730730108e-100
# 1.0 no position new buy
# 2020-11-14, BUY CREATE, 16009.52
# 2020-11-15, BUY EXECUTED, Price: 16009.52, Cost: 0.00, Comm 0.00
# Cash available: 9.454384554829955e-104
# 1.0 no position new buy
# 2020-11-15, BUY CREATE, 15856.67
# 2020-11-16, BUY EXECUTED, Price: 15856.67, Cost: 0.00, Comm 0.00
# Cash available: 6.620905503747262e-107
# 1.0 no position new buy
# 2020-11-16, BUY CREATE, 16705.77
# 2020-11-17, BUY EXECUTED, Price: 16705.77, Cost: 0.00, Comm 0.00
# Cash available: 4.6366201242737007e-110
# 1.0 no position new buy
# 2020-11-17, BUY CREATE, 17644.32
# 2020-11-18, BUY EXECUTED, Price: 17644.32, Cost: 0.00, Comm 0.00
# Cash available: 3.247025073028795e-113
# 1.0 no position new buy
# 2020-11-18, BUY CREATE, 17785.63
# 2020-11-19, BUY EXECUTED, Price: 17785.63, Cost: 0.00, Comm 0.00
# Cash available: 2.2738916586418612e-116
# 1.0 no position new buy
# 2020-11-19, BUY CREATE, 17950.99
# 2020-11-20, BUY EXECUTED, Price: 17950.99, Cost: 0.00, Comm 0.00
# Cash available: 1.5924063285469195e-119
# 1.0 no position new buy
# 2020-11-20, BUY CREATE, 18599.58
# 2020-11-21, BUY EXECUTED, Price: 18599.58, Cost: 0.00, Comm 0.00
# Cash available: 1.1151621518812784e-122
# 1.0 no position new buy
# 2020-11-21, BUY CREATE, 18670.94
# 2020-11-22, BUY EXECUTED, Price: 18670.94, Cost: 0.00, Comm 0.00
# Cash available: 7.80948054962487e-126
# 1.0 no position new buy
# 2020-11-22, BUY CREATE, 18600.60
# 2020-11-23, BUY EXECUTED, Price: 18600.60, Cost: 0.00, Comm 0.00
# Cash available: 5.4689792289016837e-129
# 1.0 no position new buy
# 2020-11-23, BUY CREATE, 18422.02
# 2020-11-24, BUY EXECUTED, Price: 18422.02, Cost: 0.00, Comm 0.00
# Cash available: 3.8299261539998164e-132
# 1.0 no position new buy
# 2020-11-24, BUY CREATE, 18944.42
# 2020-11-25, BUY EXECUTED, Price: 18944.42, Cost: 0.00, Comm 0.00
# Cash available: 2.6820972856461277e-135
# 1.0 no position new buy
# 2020-11-25, BUY CREATE, 18881.52
# 2020-11-26, BUY EXECUTED, Price: 18881.52, Cost: 0.00, Comm 0.00
# Cash available: 1.8782727291380537e-138
# 1.0 no position new buy
# 2020-11-26, BUY CREATE, 17050.01
# 2020-11-27, BUY EXECUTED, Price: 17050.01, Cost: 0.00, Comm 0.00
# Cash available: 1.31535439221537e-141
# 1.0 no position new buy
# 2020-11-27, BUY CREATE, 17002.85
# 2020-11-28, BUY EXECUTED, Price: 17002.85, Cost: 0.00, Comm 0.00
# Cash available: 9.211426808683374e-145
# 1.0 no position new buy
# 2020-11-28, BUY CREATE, 17762.22
# 2020-11-29, BUY EXECUTED, Price: 17762.22, Cost: 0.00, Comm 0.00
# Cash available: 6.450762194121091e-148
# 1.0 no position new buy
# 2020-11-29, BUY CREATE, 18274.99
# 2020-11-30, BUY EXECUTED, Price: 18274.99, Cost: 0.00, Comm 0.00
# Cash available: 4.5174687645431975e-151
# 1.0 no position new buy
# 2020-11-30, BUY CREATE, 19382.00
# 2020-12-01, BUY EXECUTED, Price: 19382.00, Cost: 0.00, Comm 0.00
# Cash available: 3.1635833758093104e-154
# 1.0 no position new buy
# 2020-12-01, BUY CREATE, 19057.46
# 2020-12-02, BUY EXECUTED, Price: 19057.46, Cost: 0.00, Comm 0.00
# Cash available: 2.2154574380794135e-157
# 1.0 no position new buy
# 2020-12-02, BUY CREATE, 19155.01
# 2020-12-03, BUY EXECUTED, Price: 19155.01, Cost: 0.00, Comm 0.00
# Cash available: 1.551484843886864e-160
# 1.0 no position new buy
# 2020-12-03, BUY CREATE, 19463.29
# 2020-12-04, BUY EXECUTED, Price: 19463.29, Cost: 0.00, Comm 0.00
# Cash available: 1.0865048361739457e-163
# 1.0 no position new buy
# 2020-12-04, BUY CREATE, 18821.50
# 2020-12-05, BUY EXECUTED, Price: 18821.50, Cost: 0.00, Comm 0.00
# Cash available: 7.608793367726237e-167
# 1.0 no position new buy
# 2020-12-05, BUY CREATE, 19018.74
# 2020-12-06, BUY EXECUTED, Price: 19018.74, Cost: 0.00, Comm 0.00
# Cash available: 5.328437995419356e-170
# 1.0 no position new buy
# 2020-12-06, BUY CREATE, 19247.64
# 2020-12-07, BUY EXECUTED, Price: 19247.64, Cost: 0.00, Comm 0.00
# Cash available: 3.73150512819201e-173
# 1.0 no position new buy
# 2020-12-07, BUY CREATE, 19079.42
# 2020-12-08, BUY EXECUTED, Price: 19079.42, Cost: 0.00, Comm 0.00
# Cash available: 2.6131730412731735e-176
# 1.0 no position new buy
# 2020-12-08, BUY CREATE, 18771.75
# 2020-12-09, BUY EXECUTED, Price: 18771.75, Cost: 0.00, Comm 0.00
# Cash available: 1.8300050808037683e-179
# 1.0 no position new buy
# 2020-12-09, BUY CREATE, 18517.51
# 2020-12-10, BUY EXECUTED, Price: 18517.51, Cost: 0.00, Comm 0.00
# Cash available: 1.2815525580868707e-182
# 1.0 no position new buy
# 2020-12-10, BUY CREATE, 18349.13
# 2020-12-11, BUY EXECUTED, Price: 18349.13, Cost: 0.00, Comm 0.00
# Cash available: 8.974712564283053e-186
# 1.0 no position new buy
# 2020-12-11, BUY CREATE, 18100.13
# 2020-12-12, BUY EXECUTED, Price: 18100.13, Cost: 0.00, Comm 0.00
# Cash available: 6.284991208767216e-189
# 1.0 no position new buy
# 2020-12-12, BUY CREATE, 18807.24
# 2020-12-13, BUY EXECUTED, Price: 18807.24, Cost: 0.00, Comm 0.00
# Cash available: 4.401379343499677e-192
# 1.0 no position new buy
# 2020-12-13, BUY CREATE, 19181.85
# 2020-12-14, BUY EXECUTED, Price: 19181.85, Cost: 0.00, Comm 0.00
# Cash available: 3.0822859542527086e-195
# 1.0 no position new buy
# 2020-12-14, BUY CREATE, 19201.26
# 2020-12-15, BUY EXECUTED, Price: 19201.26, Cost: 0.00, Comm 0.00
# Cash available: 2.158524853762609e-198
# 1.0 no position new buy
# 2020-12-15, BUY CREATE, 19429.20
# 2020-12-16, BUY EXECUTED, Price: 19429.20, Cost: 0.00, Comm 0.00
# Cash available: 1.5116149550901372e-201
# 1.0 no position new buy
# 2020-12-16, BUY CREATE, 21209.87
# 2020-12-17, BUY EXECUTED, Price: 21209.87, Cost: 0.00, Comm 0.00
# Cash available: 1.0585839530494917e-204
# 0.0 no position sit out
# 0.0 have active position sell
# 2020-12-17, SELL CREATE, 22790.14
# 2020-12-18, SELL EXECUTED, Price: 22790.14, Cost: 17212.45, Comm 10.07
# 2020-12-18, OPERATION PROFIT, GROSS 16344.41, NET 16329.18
# Cash available: 33546.79809458603
# 0.0 no position sit out
# 0.0 have active position hold positition
# Cash available: 33546.79809458603
# 1.0 no position new buy
# 2020-12-19, BUY CREATE, 23994.59
# 2020-12-20, BUY EXECUTED, Price: 23994.59, Cost: 33513.25, Comm 10.05
# Cash available: 23.492822705635774
# 1.0 no position new buy
# 2020-12-20, BUY CREATE, 23384.92
# 2020-12-21, BUY EXECUTED, Price: 23384.92, Cost: 23.47, Comm 0.01
# Cash available: 0.016452023740751758
# 1.0 no position new buy
# 2020-12-21, BUY CREATE, 23149.95
# 2020-12-22, BUY EXECUTED, Price: 23149.95, Cost: 0.02, Comm 0.00
# Cash available: 1.1521352225649252e-05
# 1.0 no position new buy
# 2020-12-22, BUY CREATE, 23440.90
# 2020-12-23, BUY EXECUTED, Price: 23440.90, Cost: 0.00, Comm 0.00
# Cash available: 8.068402963622677e-09
# 1.0 no position new buy
# 2020-12-23, BUY CREATE, 23299.97
# 2020-12-24, BUY EXECUTED, Price: 23299.97, Cost: 0.00, Comm 0.00
# Cash available: 5.650302595424424e-12
# 1.0 no position new buy
# 2020-12-24, BUY CREATE, 23409.45
# 2020-12-25, BUY EXECUTED, Price: 23409.45, Cost: 0.00, Comm 0.00
# Cash available: 3.956906907575726e-15
# 1.0 no position new buy
# 2020-12-25, BUY CREATE, 24413.58
# 2020-12-26, BUY EXECUTED, Price: 24413.58, Cost: 0.00, Comm 0.00
# Cash available: 2.7710219073755996e-18
# 1.0 no position new buy
# 2020-12-26, BUY CREATE, 26691.24
# 2020-12-27, BUY EXECUTED, Price: 26691.24, Cost: 0.00, Comm 0.00
# Cash available: 1.9405466417352263e-21
# 1.0 no position new buy
# 2020-12-27, BUY CREATE, 26388.94
# Final Portfolio Value: 36883.94

# %%
print('Returns:', strats[0].analyzers.returns.pprint())
print('Sharpe Ratio:', strats[0].analyzers.mysharpe.pprint())
print('Annual Return:', strats[0].analyzers.annualreturn.pprint())
print('Drawdown:', strats[0].analyzers.drawdown.pprint())
print('Trade Analyzer:', strats[0].analyzers.tradeanalyzer.pprint())
# Out:
# OrderedDict([('rtot', 4.727201672170566),
#              ('ravg', 0.0024143011604548345),
#              ('rnorm', 0.8374962153598383),
#              ('rnorm100', 83.74962153598383)])
# Returns: None
# OrderedDict([('sharperatio', 0.8460002844605512)])
# Sharpe Ratio: None
# OrderedDict([(2015, 1.0952955817487084),
#              (2016, 1.0605852027179923),
#              (2017, 7.384541779473119),
#              (2018, -0.6369590844017704),
#              (2019, 0.7318604625575069),
#              (2020, 3.9637959741375397)])
# Annual Return: None
# AutoOrderedDict([('len', 1),
#                  ('drawdown', 1.1325813263078186),
#                  ('moneydown', 12942.369736920344),
#                  ('max',
#                   AutoOrderedDict([('len', 546),
#                                    ('drawdown', 69.80372801832918),
#                                    ('moneydown', 262652.3433802395)]))])
# Drawdown: None
# AutoOrderedDict([('total',
#                   AutoOrderedDict([('total', 212),
#                                    ('open', 1),
#                                    ('closed', 211)])),
#                  ('streak',
#                   AutoOrderedDict([('won',
#                                     AutoOrderedDict([('current', 4),
#                                                      ('longest', 10)])),
#                                    ('lost',
#                                     AutoOrderedDict([('current', 0),
#                                                      ('longest', 6)]))])),
#                  ('pnl',
#                   AutoOrderedDict([('gross',
#                                     AutoOrderedDict([('total',
#                                                       1041294.5824599038),
#                                                      ('average',
#                                                       4935.045414501914)])),
#                                    ('net',
#                                     AutoOrderedDict([('total',
#                                                       1017569.7866615044),
#                                                      ('average',
#                                                       4822.605623988173)]))])),
#                  ('won',
#                   AutoOrderedDict([('total', 120),
#                                    ('pnl',
#                                     AutoOrderedDict([('total',
#                                                       1855364.4077727601),
#                                                      ('average',
#                                                       15461.370064773002),
#                                                      ('max',
#                                                       500178.1738960408)]))])),
#                  ('lost',
#                   AutoOrderedDict([('total', 91),
#                                    ('pnl',
#                                     AutoOrderedDict([('total',
#                                                       -837794.6211112562),
#                                                      ('average',
#                                                       -9206.534297925893),
#                                                      ('max',
#                                                       -62891.87424975463)]))])),
#                  ('long',
#                   AutoOrderedDict([('total', 211),
#                                    ('pnl',
#                                     AutoOrderedDict([('total',
#                                                       1017569.7866615044),
#                                                      ('average',
#                                                       4822.605623988173),
#                                                      ('won',
#                                                       AutoOrderedDict([('total',
#                                                                         1855364.4077727601),
#                                                                        ('average',
#                                                                         15461.370064773002),
#                                                                        ('max',
#                                                                         500178.1738960408)])),
#                                                      ('lost',
#                                                       AutoOrderedDict([('total',
#                                                                         -837794.6211112562),
#                                                                        ('average',
#                                                                         -9206.534297925893),
#                                                                        ('max',
#                                                                         -62891.87424975463)]))])),
#                                    ('won', 120),
#                                    ('lost', 91)])),
#                  ('short',
#                   AutoOrderedDict([('total', 0),
#                                    ('pnl',
#                                     AutoOrderedDict([('total', 0.0),
#                                                      ('average', 0.0),
#                                                      ('won',
#                                                       AutoOrderedDict([('total',
#                                                                         0.0),
#                                                                        ('average',
#                                                                         0.0),
#                                                                        ('max',
#                                                                         0.0)])),
#                                                      ('lost',
#                                                       AutoOrderedDict([('total',
#                                                                         0.0),
#                                                                        ('average',
#                                                                         0.0),
#                                                                        ('max',
#                                                                         0.0)]))])),
#                                    ('won', 0),
#                                    ('lost', 0)])),
#                  ('len',
#                   AutoOrderedDict([('total', 1421),
#                                    ('average', 6.734597156398104),
#                                    ('max', 93),
#                                    ('min', 1),
#                                    ('won',
#                                     AutoOrderedDict([('total', 1025),
#                                                      ('average',
#                                                       8.541666666666666),
#                                                      ('max', 93),
#                                                      ('min', 1)])),
#                                    ('lost',
#                                     AutoOrderedDict([('total', 396),
#                                                      ('average',
#                                                       4.351648351648351),
#                                                      ('max', 25),
#                                                      ('min', 1)])),
#                                    ('long',
#                                     AutoOrderedDict([('total', 1421),
#                                                      ('average',
#                                                       6.734597156398104),
#                                                      ('max', 93),
#                                                      ('min', 1),
#                                                      ('won',
#                                                       AutoOrderedDict([('total',
#                                                                         1025),
#                                                                        ('average',
#                                                                         8.541666666666666),
#                                                                        ('max',
#                                                                         93),
#                                                                        ('min',
#                                                                         1)])),
#                                                      ('lost',
#                                                       AutoOrderedDict([('total',
#                                                                         396),
#                                                                        ('average',
#                                                                         4.351648351648351),
#                                                                        ('max',
#                                                                         25),
#                                                                        ('min',
#                                                                         1)]))])),
#                                    ('short',
#                                     AutoOrderedDict([('total', 0),
#                                                      ('average', 0.0),
#                                                      ('max', 0),
#                                                      ('min',
#                                                       9223372036854775807),
#                                                      ('won',
#                                                       AutoOrderedDict([('total',
#                                                                         0),
#                                                                        ('average',
#                                                                         0.0),
#                                                                        ('max',
#                                                                         0),
#                                                                        ('min',
#                                                                         9223372036854775807)])),
#                                                      ('lost',
#                                                       AutoOrderedDict([('total',
#                                                                         0),
#                                                                        ('average',
#                                                                         0.0),
#                                                                        ('max',
#                                                                         0),
#                                                                        ('min',
#                                                                         9223372036854775807)]))]))]))])
# Trade Analyzer: None

# %%
cerebro.plot()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.9/site-packages/backtrader/plot/__init__.py in <module>
#      27 try:
# ---> 28     import matplotlib
#      29 except ImportError:
#
# ModuleNotFoundError: No module named 'matplotlib'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# /var/folders/2r/sswlrbss71z0dvg84l05n2q80000gn/T/ipykernel_66259/129914532.py in <module>
# ----> 1 cerebro.plot()
#
# /usr/local/lib/python3.9/site-packages/backtrader/cerebro.py in plot(self, plotter, numfigs, iplot, start, end, width, height, dpi, tight, use, **kwargs)
#     972
#     973         if not plotter:
# --> 974             from . import plot
#     975             if self.p.oldsync:
#     976                 plotter = plot.Plot_OldSync(**kwargs)
#
# /usr/local/lib/python3.9/site-packages/backtrader/plot/__init__.py in <module>
#      28     import matplotlib
#      29 except ImportError:
# ---> 30     raise ImportError(
#      31         'Matplotlib seems to be missing. Needed for plotting support')
#      32 else:
#
# ImportError: Matplotlib seems to be missing. Needed for plotting support
